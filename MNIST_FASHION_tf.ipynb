# %% [markdown]
# <a href="https://colab.research.google.com/github/prajapatiraghulal/TensorFlow-Course/blob/master/MNIST_FASHION_tf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
fashion_mnits = keras.datasets.fashion_mnist

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnits.load_data()

# %%
fig= plt.figure()
for i in range(1,10):
  plt.subplot(3,3,i)
  plt.imshow(train_images[i-1],cmap='gray')
  #plt.title()
  plt.colorbar()

# %%
train_images = train_images/255.0
test_images= test_images/255.0

# %%
fig= plt.figure()
for i in range(1,10):
  plt.subplot(3,3,i)
  plt.imshow(train_images[i-1],cmap='gray')
  #plt.title()
  plt.colorbar()

# %%
model = keras.Sequential([ 
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128, activation=tf.nn.relu),
                          keras.layers.Dense(10, activation=tf.nn.softmax)])

# %%
model.compile(optimizer='adamax', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3165 - accuracy: 0.8875
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3061 - accuracy: 0.8899
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2951 - accuracy: 0.8934
# Epoch 4/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2886 - accuracy: 0.8968
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2803 - accuracy: 0.8993
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2737 - accuracy: 0.9016
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2670 - accuracy: 0.9030
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2617 - accuracy: 0.9056
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2558 - accuracy: 0.9072
# Epoch 10/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 968us/step - loss: 0.3341 - accuracy: 0.8804

# %%
print(test_acc)
# Out:
# 0.8804000020027161

# %%
predictions = model.predict(test_images)
predictions[0]
# Out:
# array([9.5616715e-06, 1.9089740e-08, 2.3712657e-06, 4.4089094e-07,
#        6.6572483e-07, 9.0822494e-03, 6.1051060e-06, 1.3550566e-02,
#        1.7587554e-04, 9.7717208e-01], dtype=float32)

# %%
#x=np.array(predictions[0])  and x.argmax()
#or np.argmax(predictions[0])

predictions[0].argmax()
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9
